# %%
import json
import os
from library_dicom.dicom_processor.model.Series import Series 
from library_dicom.dicom_processor.model.SeriesPT import SeriesPT
from library_dicom.dicom_processor.model.SeriesCT import SeriesCT
from library_dicom.dicom_processor.model.csv_reader.MaskBuilder import MaskBuilder

from library_dicom.dicom_processor.tools.folders import *

from library_dicom.dicom_processor.tools.create_mip import *
from library_dicom.dicom_processor.tools.threshold_mask import *

import numpy as np
import SimpleITK as sitk

import csv

# %%
json_path = '/media/salim/DD 2To/GAINED_NIFTI/json/dataset_1.json'
dataset_1 = []
with open(json_path) as json_file : 
    reader = json.load(json_file)
    for info in reader :
        dataset_1.append(info)

print(len(dataset_1))
# Out:
# 140

# %%
#index
coronal = [8]
error = [80, 135]
false_mask = [13, 14, 17, 18, 19, 39, 42, 47, 48, 51, 53, 54, 57, 58, 59, 61, 62, 63, 64, 65, 67, 68, 69, 74, 76, 86, 88, 97, 100, 108, 111, 112, 113, 115, 117, 119, 122, 124, 128, 132, 133, 134, 136, 137, 138, 139]
print(len(false_mask))
# Out:
# 46

# %%
good = [5, 10, 12,14, 16, 17, 18, 22, 25, 26, 28,29, 30, 31, 32, 33, 38, 39, 40, 41, 42, 45]
false_mask[45]
# Out:
# 139

# %%
print(len(good))
data = []
for i in good : 
    data.append(false_mask[i])


for index in data : 
    false_mask.remove(index)

print(len(false_mask))
# Out:
# 22
# 24

# %%
serie_mip = []
for index in false_mask : 
    serie_mip.append(dataset_1[index])

# %%
mip_directory = '/media/salim/DD 2To/GAINED_MIP'
csv_directory = '/media/salim/DD 2To/GAINED_CSV_DATA/Export_Gained/CSV41/PET0'

for serie in serie_mip: 
        print(serie_mip.index(serie))
        if serie[1] == 'PT' : 
                serie_pt_objet = SeriesPT(serie[0])
                nifti_array = serie_pt_objet.get_numpy_array()
                study_uid = serie_pt_objet.get_series_details()['study']['StudyInstanceUID']

                angle_filename = mip_projection(nifti_array, 0, mip_directory, study_uid, borne_max = 5.0)             #mip.png PET


                size_matrix = serie_pt_objet.get_size_matrix()
                mask_objet = MaskBuilder(os.path.join(csv_directory, serie[6]), size_matrix)
                mask_4D = mask_objet.mask_array


                number_roi = mask_4D.shape[3]
                threshold = mask_objet.details_rois['SUVlo']
                        #seuillage
                mask_4D = threshold_mask(mask_4D, mask_objet.details_rois, nifti_array)
                angle_filename_mask = mip_projection_4D(mask_4D, 0, mip_directory, study_uid, number_roi, borne_max = 1.0)
                print(mask_objet.calcul_suv(nifti_array))
                print(mask_objet.ecart_suv_max(nifti_array))
                print(mask_objet.ecart_suv_mean(nifti_array))
                print(mask_objet.ecart_SD(nifti_array))
                
                        #mip.png MASK
        else  : 
                serie_pt_objet = SeriesPT(serie[2])
                nifti_array = serie_pt_objet.get_numpy_array()
                study_uid = serie_pt_objet.get_series_details()['study']['StudyInstanceUID']

                angle_filename = mip_projection(nifti_array, 0, mip_directory, study_uid, borne_max = 5.0)             #mip.png PET


                size_matrix = serie_pt_objet.get_size_matrix()
                mask_objet = MaskBuilder(os.path.join(csv_directory, serie[6]), size_matrix)
                mask_4D = mask_objet.mask_array


                number_roi = mask_4D.shape[3]
                threshold = mask_objet.details_rois['SUVlo']
                        #seuillage
                mask_4D = threshold_mask(mask_4D, mask_objet.details_rois, nifti_array)
                angle_filename_mask = mip_projection_4D(mask_4D, 0, mip_directory, study_uid, number_roi, borne_max = 1.0)
                print(mask_objet.calcul_suv(nifti_array))
                print(mask_objet.ecart_suv_max(nifti_array))
                print(mask_objet.ecart_suv_mean(nifti_array))
                print(mask_objet.ecart_SD(nifti_array))
# Out:
# 0
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# OSError: [Errno 28] No space left on device
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f9f859b37d0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f9f859b37d0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     420         with fh:
# --> 421             yield fh
#     422     else:
#
# ~/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     535             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
# --> 536                 _png.write_png(renderer._renderer, fh, self.figure.dpi,
#     537                                metadata={**default_metadata, **metadata})
#
# SystemError: <built-in method write of _io.BufferedWriter object at 0x7f9f859b37d0> returned a result with an error set
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-db7c2c2965fe> in <module>
#      33                 study_uid = serie_pt_objet.get_series_details()['study']['StudyInstanceUID']
#      34
# ---> 35                 angle_filename = mip_projection(nifti_array, 0, mip_directory, study_uid, borne_max = 5.0)             #mip.png PET
#      36
#      37
#
# ~/library-DICOM/library_dicom/dicom_processor/tools/create_mip.py in mip_projection(numpy_array, angle, path_image, study_uid, borne_max)
#      47     #angle_filename = path_image+'\\'+study_uid+'mip'+"."+str(int(angle))+".png" #rajouter le study iud du patient ou numero de serie
#      48     angle_filename = os.path.join(path_image, filename)
# ---> 49     f.savefig(angle_filename, bbox_inches='tight')
#      50     plt.close()
#      51     return angle_filename
#
# ~/.local/lib/python3.8/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# ~/.local/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2096
#    2097             try:
# -> 2098                 result = print_method(
#    2099                     filename,
#    2100                     dpi=dpi,
#
# ~/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     534             renderer = self.get_renderer()
#     535             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
# --> 536                 _png.write_png(renderer._renderer, fh, self.figure.dpi,
#     537                                metadata={**default_metadata, **metadata})
#     538
#
# /usr/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     129                 value = type()
#     130             try:
# --> 131                 self.gen.throw(type, value, traceback)
#     132             except StopIteration as exc:
#     133                 # Suppress StopIteration *unless* it's the same exception that
#
# ~/.local/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     419     if opened:
#     420         with fh:
# --> 421             yield fh
#     422     else:
#     423         yield fh
#
# OSError: [Errno 28] No space left on device

# %%
mask_objet.calcul_suv(nifti_array)
# Out:
# {1: {'SUV_max': 10.94, 'SUV_mean': 6.19, 'SD': 1.49},
#  2: {'SUV_max': 8.28, 'SUV_mean': 5.35, 'SD': 1.33},
#  3: {'SUV_max': 6.51, 'SUV_mean': 3.98, 'SD': 1.14},
#  4: {'SUV_max': 9.56, 'SUV_mean': 5.78, 'SD': 1.41},
#  5: {'SUV_max': 7.67, 'SUV_mean': 4.74, 'SD': 1.19},
#  6: {'SUV_max': 6.87, 'SUV_mean': 4.17, 'SD': 0.99},
#  7: {'SUV_max': 14.05, 'SUV_mean': 8.9, 'SD': 2.16},
#  8: {'SUV_max': 17.45, 'SUV_mean': 9.86, 'SD': 2.34},
#  9: {'SUV_max': 4.88, 'SUV_mean': 3.18, 'SD': 0.55},
#  10: {'SUV_max': 15.44, 'SUV_mean': 8.5, 'SD': 1.71},
#  11: {'SUV_max': 19.6, 'SUV_mean': 11.37, 'SD': 3.11},
#  12: {'SUV_max': 14.76, 'SUV_mean': 9.09, 'SD': 2.25},
#  13: {'SUV_max': 8.68, 'SUV_mean': 4.85, 'SD': 1.19},
#  14: {'SUV_max': 6.75, 'SUV_mean': 3.4, 'SD': 0.75},
#  15: {'SUV_max': 21.47, 'SUV_mean': 12.94, 'SD': 2.94},
#  16: {'SUV_max': 9.78, 'SUV_mean': 6.01, 'SD': 1.78},
#  17: {'SUV_max': 30.94, 'SUV_mean': 16.9, 'SD': 3.65},
#  18: {'SUV_max': 14.63, 'SUV_mean': 10.13, 'SD': 2.61},
#  19: {'SUV_max': 14.09, 'SUV_mean': 8.09, 'SD': 1.86},
#  20: {'SUV_max': 22.39, 'SUV_mean': 13.1, 'SD': 3.45},
#  21: {'SUV_max': 10.62, 'SUV_mean': 6.1, 'SD': 1.51},
#  22: {'SUV_max': 20.76, 'SUV_mean': 12.58, 'SD': 3.78},
#  23: {'SUV_max': 6.83, 'SUV_mean': 4.37, 'SD': 1.18},
#  24: {'SUV_max': 14.21, 'SUV_mean': 8.68, 'SD': 2.12},
#  25: {'SUV_max': 16.35, 'SUV_mean': 10.17, 'SD': 2.8},
#  26: {'SUV_max': 18.68, 'SUV_mean': 10.83, 'SD': 2.61},
#  27: {'SUV_max': 20.9, 'SUV_mean': 12.84, 'SD': 3.5},
#  28: {'SUV_max': 9.26, 'SUV_mean': 5.63, 'SD': 1.51},
#  29: {'SUV_max': 6.64, 'SUV_mean': 4.79, 'SD': 1.24},
#  30: {'SUV_max': 8.22, 'SUV_mean': 4.85, 'SD': 1.33},
#  31: {'SUV_max': 20.86, 'SUV_mean': 12.0, 'SD': 3.02},
#  32: {'SUV_max': 12.52, 'SUV_mean': 8.51, 'SD': 2.27}}

# %%
print(mask_objet.ecart_suv_max(nifti_array))
print(mask_objet.ecart_suv_mean(nifti_array))
print(mask_objet.ecart_SD(nifti_array))
# Out:
# []
# []
# []
