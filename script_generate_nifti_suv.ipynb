# %%
from library_dicom.dicom_processor.model.NiftiBuilder import NiftiBuilder
import os
import json

from library_dicom.dicom_processor.model.Series import Series
from library_dicom.dicom_processor.model.SeriesPT import SeriesPT
from library_dicom.dicom_processor.tools.folders import get_series_path, write_json_file, remove_bi_file
from library_dicom.dicom_processor.tools.series import get_series_object

# %%
file = r'C:\Users\wendy\Documents\STAGE\DicomRT\201802409 BARAT GALPIN ELIANE\103893708 Tepscan FDG\RTSTRUCT PETVCAR RTSS RTSS'

# %%
rt = Series(file)

# %%
rt.get_number_of_files()
# Out:
# 1

# %%
rt.get_series_details()
# Out:
# {'series': {'ImageType': 'Undefined',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'Modality': 'RTSTRUCT',
#   'SeriesDate': 'Undefined',
#   'SeriesTime': 'Undefined',
#   'SeriesDescription': 'PETVCAR RTSS - RTSS',
#   'SeriesInstanceUID': '1.2.840.113619.2.80.1303088600.31043.1589463282.2',
#   'SeriesNumber': "103",
#   'AcquisitionDate': 'Undefined',
#   'AcquisitionTime': 'Undefined',
#   'NumberOfSlices': 'Undefined',
#   'ImageInAcquisition': 'Undefined',
#   'Units': 'Undefined',
#   'DecayCorrection': 'Undefined'},
#  'study': {'AccessionNumber': '103893708',
#   'InstitutionName': 'Undefined',
#   'StudyDate': '20180315',
#   'StudyTime': '105020',
#   'StudyDescription': 'Tep-scan FDG',
#   'StudyID': '18575',
#   'StudyInstanceUID': '1.2.840.113619.2.354.3.3523896338.709.1521096511.515',
#   'PatientWeight': 'Undefined',
#   'PatientHeight': 'Undefined'},
#  'patient': {'PatientName': 'BARAT - GALPIN^ELIANE',
#   'PatientID': '201802409',
#   'PatientBirthDate': '19510426',
#   'PatientSex': 'F'},
#  'path': 'C:\\Users\\wendy\\Documents\\STAGE\\DicomRT\\201802409 BARAT GALPIN ELIANE\\103893708 Tepscan FDG\\RTSTRUCT PETVCAR RTSS RTSS',
#  'files': 1}

# %%
series_pet.get_numpy_array().shape
# Out:
# (256, 256, 299)

# %%
series_pet.export_nifti(r'C:\Users\wendy\Documents\STAGE\CSV CHALLENGE\nifti\nifti_example1.nii')
# Out:
# [1, 0, 0, 0, 1, -0]
# ["-974.46002197265", "-971.1900024414", "-967.92004394531", "-964.65002441406", "-961.38000488281", "-958.11004638671", "-954.84002685546", "-951.57000732421", "-948.30004882812", "-945.03002929687", "-941.76000976562", "-938.49005126953", "-935.22003173828", "-931.95001220703", "-928.67999267578", "-925.41003417968", "-922.14001464843", "-918.86999511718", "-915.60003662109", "-912.33001708984", "-909.05999755859", "-905.7900390625", "-902.52001953125", "-899.25", "-895.9800415039", "-892.71002197265", "-889.4400024414", "-886.17004394531", "-882.90002441406", "-879.63000488281", "-876.36004638671", "-873.09002685546", "-869.82000732421", "-866.55004882812", "-863.28002929687", "-860.01000976562", "-856.73999023437", "-853.46997070312", "-850.20001220703", "-846.92999267578