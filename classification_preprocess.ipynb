# %%
import SimpleITK as sitk 
import numpy as np 
import matplotlib.pyplot as plt

# %%
image = '/media/deeplearning/Elements/classif_ct/test_mip_ct_nifti_.nii'

# %%
img = sitk.ReadImage(image)
array = sitk.GetArrayFromImage(img)

# %%
array.shape
# Out:
# (1024, 256)

# %%
f = plt.figure(figsize=(9,9))
axes = plt.gca()
axes.set_axis_off()
plt.imshow(array)
