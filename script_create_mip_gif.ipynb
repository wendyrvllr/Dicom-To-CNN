# %%
from library_dicom.dicom_processor.model.SeriesPT import SeriesPT
from library_dicom.dicom_processor.model.SeriesCT import SeriesCT
from library_dicom.dicom_processor.tools.create_mip import create_gif, mip_projection, create_mip_gif


import matplotlib.pyplot as plt 
import numpy as np
import scipy.ndimage
import os 
import imageio
from os.path import basename,splitext

# %%
CT_path = r'C:\Users\wendy\Documents\STAGE\CSV CHALLENGE\1.2.840.113704.1.111.5096.1271246941.8'

# %%
gif_directory = r'C:\Users\wendy\Documents\STAGE\mip'

# %%
serie = SeriesCT(CT_path)
nifti_array = serie.get_numpy_array()

# %%
nifti_array.shape
# Out:
# (512, 512, 204)

# %%
plt.imshow(np.amax(nifti_array[:,:,:], axis = 0))

# %%
PT_path =  r'C:\Users\wendy\Documents\STAGE\CSV CHALLENGE\1.3.46.670589.28.2.12.4.9177.6631.2.448.0.1271249841'

# %%
serie_pt = SeriesPT(PT_path)
nifti_array_pet = serie_pt.get_numpy_array()

# %%
nifti_array_pet.shape
# Out:
# (144, 144, 255)

# %%
plt.imshow(np.amax(nifti_array_pet, axis = 0))

# %%
create_mip_gif(nifti_array, gif_directory, 'study_uid', borne_max = 5.0)
